# %% [markdown]
# # Como usar R en Collab

# %% [markdown]
# Cargamos la version de r-magic 3.5.1

# %%
# !pip install --upgrade rpy2==3.5.1

# %% [markdown]
# Activamos el lenguaje de programación de R.

# %%
#Activar r-magic
# %reload_ext rpy2.ipython

# %% [markdown]
# ## Ejemplo de aplicacion y mezcla de lenguajes de programación.

# %% [markdown]
# Definimos un data.frame en python

# %%
#Permite reconocer como dataframe con pandas, o sea, que se pueden recorrer
import pandas as pd
pd.DataFrame.iteritems = pd.DataFrame.items

# %%
y = 450

# %%
df_loan = pd.read_csv('https://raw.githubusercontent.com/gedeck/practical-statistics-for-data-scientists/master/data/loans_income.csv') #importar archivos de

# %%
df_loan.head()
# Out:
#         x
# 0   67000
# 1   52000
# 2  100000
# 3   78762
# 4   37041

# %% [markdown]
# Ahora, para trabajar en ambiente de R ("%%" para trabajar todo el bloque como R, "%" para una sola linea de codigo)

# %%
# %%R -i y #para traer el "y" creado en Python (-i para importar)
#
# x <- 40
# print(x+y)
# Out:
# [1] 490

# %%
# %%R -i df_loan
# df_loan <- data.frame(df_loan)
# head(df_loan)
# Out:
#        x
# 0  67000
# 1  52000
# 2 100000
# 3  78762
# 4  37041
# 5  33000

# %% [markdown]
# Podemos tambien, exportar lo trabajado en R a python.

# %%
# %R -o x
x_var = x

print(x_var)
# Out:
# [40.]

# %% [markdown]
# cuando salen de R a Python, salen como lista, por ende se tiene que definir nuevamente como variable.

# %%
# %%R
# df <- data.frame(dose=c("D0.5", "D1", "D2"),
#                  len=c(4.2,10,29.5))
# head(df)
# Out:
#   dose  len
# 1 D0.5  4.2
# 2   D1 10.0
# 3   D2 29.5

# %%
# %R -o df

# %%
df
# Out:
#    dose   len
# 1  D0.5   4.2
# 2    D1  10.0
# 3    D2  29.5

# %% [markdown]
# Tambien es posible instalar paquetes de R

# %%
# %%R
# install.packages('caret')
# #install.pacakges('mlbench')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/listenv_0.9.1.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 36600 bytes (35 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...
